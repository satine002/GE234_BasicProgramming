# %% [markdown]
# <a href="https://colab.research.google.com/github/satine002/GE234_BasicProgramming/blob/main/Lab2_GE234_Loop_IfElse_6706615009.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🛰️ Lab 2: การใช้งาน Loop และ If-Else
# ## วิชา GE 234 Basic Programming for Geographers
#
# ### 🎯 **วัตถุประสงค์**
# 1. เข้าใจโครงสร้างการควบคุมแบบ **Loop** (`for`, `while`) และ **เงื่อนไข** (`if-else`)
# 2. สามารถใช้ `for` และ `while` loop เพื่อประมวลผลข้อมูลซ้ำ ๆ ได้
# 3. ใช้ `if-else` เพื่อกำหนดเงื่อนไขในการตัดสินใจ
# 4. นำไปประยุกต์ใช้กับข้อมูลทางภูมิศาสตร์ เช่น การคัดกรองข้อมูลพิกัดและการวิเคราะห์ข้อมูล Raster
#
# ---
#
# ## 🔹 ตัวอย่างที่ 1: การใช้ `for loop` เพื่อแสดงค่าพิกัด

# %%
# พิกัดของสถานที่สำคัญในประเทศไทย
locations = {
    "Bangkok": (13.7563, 100.5018),
    "Chiang Mai": (18.7883, 98.9853),
    "Phuket": (7.8804, 98.3923),
    "Ubon Ratchathani": (15.2287, 104.8564)
}

# วนลูปแสดงค่าพิกัด
for city, coord in locations.items():
    print(f"{city}: Latitude {coord[0]}, Longitude {coord[1]}")
# Out:
# Bangkok: Latitude 13.7563, Longitude 100.5018
# Chiang Mai: Latitude 18.7883, Longitude 98.9853
# Phuket: Latitude 7.8804, Longitude 98.3923
# Ubon Ratchathani: Latitude 15.2287, Longitude 104.8564

# %% [markdown]
# ## 🔹 ตัวอย่างที่ 2: การใช้ `if-else` กรองข้อมูลพิกัด

# %%
for city, coord in locations.items():
    if coord[0] > 16:
        print(f"{city} อยู่ทางภาคเหนือของประเทศไทย")
    else:
        print(f"{city} ไม่ใช่จังหวัดทางภาคเหนือ")
# Out:
# Bangkok ไม่ใช่จังหวัดทางภาคเหนือ
# Chiang Mai อยู่ทางภาคเหนือของประเทศไทย
# Phuket ไม่ใช่จังหวัดทางภาคเหนือ
# Ubon Ratchathani ไม่ใช่จังหวัดทางภาคเหนือ

# %% [markdown]
# ## 🔹 ตัวอย่างที่ 3: ใช้ `while loop` นับจำนวนจุดข้อมูล

# %%
points = [(13.7563, 100.5018), (18.7883, 98.9853), (7.8804, 98.3923)]
count = 0

while count < len(points):
    print(f"Point {count + 1}: {points[count]}")
    count += 1
# Out:
# Point 1: (13.7563, 100.5018)
# Point 2: (18.7883, 98.9853)
# Point 3: (7.8804, 98.3923)

# %% [markdown]
# ## 🔹 ตัวอย่างที่ 4: วิเคราะห์ข้อมูล Raster ด้วย `for loop`

# %%
import numpy as np

# จำลองข้อมูล NDVI (Normalized Difference Vegetation Index)
ndvi = np.array([
    [0.2, 0.4, 0.5],
    [0.1, 0.3, 0.7],
    [0.6, 0.8, 0.2]
])

# วนลูปตรวจสอบค่าพืชพรรณ
for row in range(ndvi.shape[0]):
    for col in range(ndvi.shape[1]):
        if ndvi[row, col] > 0.3:
            print(f"พิกัด ({row}, {col}) มีพืชพรรณหนาแน่น (NDVI={ndvi[row, col]})")
# Out:
# พิกัด (0, 1) มีพืชพรรณหนาแน่น (NDVI=0.4)
# พิกัด (0, 2) มีพืชพรรณหนาแน่น (NDVI=0.5)
# พิกัด (1, 2) มีพืชพรรณหนาแน่น (NDVI=0.7)
# พิกัด (2, 0) มีพืชพรรณหนาแน่น (NDVI=0.6)
# พิกัด (2, 1) มีพืชพรรณหนาแน่น (NDVI=0.8)

# %% [markdown]
# # 📝 **กิจกรรมในแลป**
#
# 1. **แบบฝึกหัด 1**: เขียน `for loop` เพื่อแสดงชื่อจังหวัดและพิกัดจากลิสต์ของคุณเอง
# 2. **แบบฝึกหัด 2**: ใช้ `if-else` เพื่อแยกแยะพื้นที่ที่เป็นภูเขาและพื้นที่ราบจากลิสต์ของพิกัด
# 3. **แบบฝึกหัด 3**: ใช้ `while loop` เพื่อวนลูปและแสดงค่าละติจูดจากลิสต์จนกว่าจะพบค่าต่ำกว่า 10°
# 4. **แบบฝึกหัด 4**: ใช้ `for loop` วิเคราะห์ค่า NDVI และหาค่าพื้นที่ที่มีสภาพแห้งแล้ง (NDVI < 0.2)

# %% [markdown]
# แหล่งที่มา : https://github.com/dataengineercafe/thailand-province-latitude-longitude

# %%
# แบบฝึกหัด 1 พิกัดของจังหวัดในประเทศไทย
locations = {
    "Bangkok": (13.7563, 100.5018),
    "Chiang Mai": (18.7883, 98.9853),
    "Phuket": (7.8804, 98.3923),
    "Ubon Ratchathani": (15.2287, 104.8564),
    "Narathiwat": (6.4254, 101.8253),
    "Mae Hong Son": (19.2991, 97.9656),
    "Pattani": (6.8694, 101.2504),
    "Nan": (18.7756, 100.7730),
    "Nakhon Pathom": (13.8199, 100.0621),
    "Ratchaburi": (13.6333, 99.1733)
}

# วนลูปแสดงค่าพิกัด
for city, coord in locations.items():
    print(f"{city}: Latitude {coord[0]}, Longitude {coord[1]}")
# Out:
# Bangkok: Latitude 13.7563, Longitude 100.5018
# Chiang Mai: Latitude 18.7883, Longitude 98.9853
# Phuket: Latitude 7.8804, Longitude 98.3923
# Ubon Ratchathani: Latitude 15.2287, Longitude 104.8564
# Narathiwat: Latitude 6.4254, Longitude 101.8253
# Mae Hong Son: Latitude 19.2991, Longitude 97.9656
# Pattani: Latitude 6.8694, Longitude 101.2504
# Nan: Latitude 18.7756, Longitude 100.773
# Nakhon Pathom: Latitude 13.8199, Longitude 100.0621
# Ratchaburi: Latitude 13.6333, Longitude 99.1733

# %%
# แบบฝึกหัด 2

for city, coord in locations.items():
    if coord[0] > 16:
        print(f"{city} อยู่ทางภาคเหนือของประเทศไทย")
    elif coord[0] < 16 and coord[0] > 11 :
        print(f"{city} อยู่ทางภาคกลาง ภาคตะวันออก และภาคตะวันตกของประเทศไทย")
    elif coord[0] < 11:
        print(f"{city} อยู่ทางภาคใต้ของประเทศไทย")
# Out:
# Bangkok อยู่ทางภาคกลาง ภาคตะวันออก และภาคตะวันตกของประเทศไทย
# Chiang Mai อยู่ทางภาคเหนือของประเทศไทย
# Phuket อยู่ทางภาคใต้ของประเทศไทย
# Ubon Ratchathani อยู่ทางภาคกลาง ภาคตะวันออก และภาคตะวันตกของประเทศไทย
# Narathiwat อยู่ทางภาคใต้ของประเทศไทย
# Mae Hong Son อยู่ทางภาคเหนือของประเทศไทย
# Pattani อยู่ทางภาคใต้ของประเทศไทย
# Nan อยู่ทางภาคเหนือของประเทศไทย
# Nakhon Pathom อยู่ทางภาคกลาง ภาคตะวันออก และภาคตะวันตกของประเทศไทย
# Ratchaburi อยู่ทางภาคกลาง ภาคตะวันออก และภาคตะวันตกของประเทศไทย

# %%
#แบบฝึกหัด 3 วนลูปและแสดงค่าละติจูดจากลิสต์จนกว่าจะพบค่าต่ำกว่า 10°

points = [(13.7563, 100.5018), (18.7883, 98.9853), (7.8804, 98.3923)]
count = 0

while count < len(points):
    latitude = points[count][0]
    print(f"Point {count + 1}: Latitude {latitude}, Longitude {points[count][1]}")
    if latitude < 10:
        print(f"พบค่าละติจูดต่ำกว่า 10 องศาที่ Point {count + 1} ({latitude}°). หยุดการวนลูป.")
        break
    count += 1
# Out:
# Point 1: Latitude 13.7563, Longitude 100.5018
# Point 2: Latitude 18.7883, Longitude 98.9853
# Point 3: Latitude 7.8804, Longitude 98.3923
# พบค่าละติจูดต่ำกว่า 10 องศาที่ Point 3 (7.8804°). หยุดการวนลูป.

# %%
#แบบฝึกหัด 4
import numpy as np

# จำลองข้อมูล NDVI (Normalized Difference Vegetation Index)
ndvi = np.array([
    [0.2, 0.4, 0.5],
    [0.1, 0.3, 0.7],
    [0.6, 0.8, 0.2]
])

# วนลูปตรวจสอบค่าพืชพรรณ
for row in range(ndvi.shape[0]):
    for col in range(ndvi.shape[1]):
        if ndvi[row, col] > 0.3:
            print(f"พิกัด ({row}, {col}) มีพืชพรรณหนาแน่น (NDVI={ndvi[row, col]})")
        elif ndvi[row, col] < 0.2:
            print(f"พิกัด ({row}, {col}) มีสภาพแห้งแล้ง (NDVI={ndvi[row, col]})")
# Out:
# พิกัด (0, 1) มีพืชพรรณหนาแน่น (NDVI=0.4)
# พิกัด (0, 2) มีพืชพรรณหนาแน่น (NDVI=0.5)
# พิกัด (1, 0) มีสภาพแห้งแล้ง (NDVI=0.1)
# พิกัด (1, 2) มีพืชพรรณหนาแน่น (NDVI=0.7)
# พิกัด (2, 0) มีพืชพรรณหนาแน่น (NDVI=0.6)
# พิกัด (2, 1) มีพืชพรรณหนาแน่น (NDVI=0.8)
